# %%
import random
import pprint

# 리스트 생성
# nnew = ['P' + str(i + 1) + s for i in range(6) for s in ['A', 'B']]
# nnnw = nnew * 2

def extractor(time, lst_t):
    lst = []
    gi = False
    for i in range(time): #  time에 입력한 수만큼 반복
        value = random.choice(lst_t)
        if value in lst:
            gi = True
        while gi == True:
            index = [v for v in lst_t if v.startswith(value[0:3]) == False]
            value = random.choice(index)
            if value not in lst:
                gi = False

        nnnw.remove(value)
        lst.append(value)
        
    lst.sort()
    return lst


# llst = [[],[],[],[],[]] 

def enter(jk):
    for i in range(len(jk)):

        if i == 0:
            a = extractor(4, nnnw)
            for s in a: # 시간표담기
                jk[i].append(s) 
            
        else:
            p = []
            for c in jk[i-1]:
                d = [v for v in nnnw if v.startswith(c[0:3]) == False]
                p.append(d) 
            itsc = list(set(p[0]) & set(p[1]) & set(p[2]) & set(p[3]))

            a = extractor(4, itsc)
            
            for s in a: # 시간표담기
                jk[i].append(s) 
    if len(set(nnnw)) == 3:
        nnnw.sort()
        jk.append(nnnw)
        return jk
    else: 
        return True
    
plend = []
tne = False
for gin in range(10):
    nnew = ['P' + str(i + 1) + s for i in range(6) for s in ['A', 'B']]
    nnnw = nnew * 2


    llst = [[],[],[],[],[]] 

    
    tne = enter(llst)
    if not tne == True:
        plend.append(tne)

elend = []
for u in plend:
    den = u[0] + u[1]
    ten = u[3] + u[4]
    check = 'str'
    ni = '0'

    for y in u[5]:
        if y == ni:
            check = y
        ni = y
    index2 = [s for s in u[5] if not s == check]

    dencount = 0
    tencount = 0

    for x in index2:
        if x in den:
            dencount += 1
        if x in ten:
            tencount += 1
    print(u)
    print(dencount, tencount)

    if not (dencount == 2 or tencount == 2):
        elend.append(u)

elend

# %%
lst_table = [['a' + str(i+1) for i in range(5)],
             ['b' + str(i+1) for i in range(5)],
             ['c' + str(i+1) for i in range(4)],
             ['d' + str(i+1) for i in range(5)],
             ['e' + str(i+1) for i in range(5)]]

a = [len(i) for i in lst_table]
a
# Out:
# [5, 5, 4, 5, 5]

# %%
import random

lst_lecture = ['P' + str(i + 1) + s for i in range(6) for s in ['A', 'B']] * 2
lst_table = [['a' + str(i+1) for i in range(5)],
             ['b' + str(i+1) for i in range(5)],
             ['c' + str(i+1) for i in range(4)],
             ['d' + str(i+1) for i in range(5)],
             ['e' + str(i+1) for i in range(5)]]

def extractor(time, lst):
    lst_bin = []
    key_inbin = False
    for i in range(time): #  time에 입력한 수만큼 반복
        chosen = random.choice(lst)
        if chosen in lst_bin:
            key_inbin = True
        while key_inbin == True:
            # index = [v for v in lst if v.startswith(chosen[0:3]) == False]
            index = [v for v in lst if not v == chosen]
            chosen = random.choice(index)
            if chosen not in lst_bin:
                key_inbin = False

        lst_lecture.remove(chosen)
        lst_bin.append(chosen)
        
    lst_bin.sort()
    return lst_bin

# if len(lst_lecture) > len([ele for day in lst_table for ele in day]):
#     print('강좌 수 초과')
# else:
#     quo, rem = divmod(len(lst_lecture), len(lst_table))

# extractor(quo, lst_lecture)
jk = []
n = 0
for intable in lst_table:
    n += 1
    len_table = len(intable)
    print(extractor(len_table, lst_lecture))
    
    if n == 1:
        a = extractor(len_table, lst_lecture)
        jk.append(a)
        # for s in a: # 시간표담기
        #     jk[n-1].append(s)
    elif n == 3:



def enter(jk):
    for i in range(len(jk)):

        if i == 0:
            a = extractor(quo, lst_lecture)
            for s in a: # 시간표담기
                jk[i].append(s) 
            
        else:
            p = []
            for c in jk[i-1]:
                d = [v for v in lst_lecture if v.startswith(c[0:3]) == False]
                p.append(d) 
            itsc = list(set(p[0]) & set(p[1]) & set(p[2]) & set(p[3]))

            a = extractor(quo, itsc)
            
            for s in a: # 시간표담기
                jk[i].append(s) 
    if len(set(lst_lecture)) == 3:
        lst_lecture.sort()
        jk.append(lst_lecture)
        return jk
    else: 
        return True
# Out:
# ['P2A', 'P2B', 'P3A', 'P3B', 'P4B']
# 7
# ['P1A', 'P1B', 'P2A', 'P5B', 'P6A']
# ['P2B', 'P3A', 'P5A', 'P6B']
# ['P3B', 'P4A', 'P4B', 'P6A', 'P6B']
# ['P1A', 'P1B', 'P4A', 'P5A', 'P5B']

# %%
import random
import pprint

lst_lecture = ['P' + str(i + 1) + s for i in range(6) for s in ['A', 'B']] * 2
lst_table = [['a' + str(i+1) for i in range(5)],
             ['b' + str(i+1) for i in range(5)],
             ['c' + str(i+1) for i in range(4)],
             ['d' + str(i+1) for i in range(5)],
             ['e' + str(i+1) for i in range(5)]]


if len(lst_lecture) > len([ele for day in lst_table for ele in day]):
    print('강좌 수 초과')
else:
    quo, rem = divmod(len(lst_lecture), len(lst_table))


def extractor(time, lst):
    lst_bin = []
    # key_inbin = False
    
    for i in range(time): 
        key_inbin = False
        for choose in lst:
            chosen = choose
            if chosen in lst_bin:
                index = [v for v in lst if not v == chosen]
            else:
                lst_bin.append(chosen)
        



        lst_lecture.remove(chosen)
        lst_bin.append(chosen)
        
    lst_bin.sort()
    return lst_bin, key_inbin
extractor(quo, lst_lecture)
